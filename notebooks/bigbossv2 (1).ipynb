# %%
import pandas as pd
import numpy as np
# from google.colab import files
# csvsheet=files.upload()

# %%
import io
data=pd.read_csv(io.BytesIO(csvsheet['datav1_4.csv']))

# %%
data
# Out:
#       Unnamed: 0  ...                              link
# 0              1  ...                               NaN
# 1              2  ...                               NaN
# 2              3  ...                               NaN
# 3              4  ...                               NaN
# 4              5  ...  /wiki/Pachai_Vilakku_(2020_film)
# ...          ...  ...                               ...
# 1703        1704  ...      /wiki/Thenmerku_Paruvakaatru
# 1704        1705  ...                       /wiki/Kotti
# 1705        1706  ...        /wiki/Mudhal_Kadhal_Mazhai
# 1706        1707  ...                  /wiki/Nalamdhana
# 1707        1708  ...                    /wiki/Villalan
#
# [1708 rows x 8 columns]

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data['music']=''

# %%
data
# Out:
#       year  ... music
# 0     2020  ...
# 1     2020  ...
# 2     2020  ...
# 3     2020  ...
# 4     2020  ...
# ...    ...  ...   ...
# 1703  2010  ...
# 1704  2010  ...
# 1705  2010  ...
# 1706  2010  ...
# 1707  2010  ...
#
# [1708 rows x 8 columns]

# %%
data.iloc[0]
# Out:
# year                                  2020
# title                        Anantha Veedu
# director                         Sugumaran
# cast        Sugumaran, Shivayam, Nagarajan
# genre                                  NaN
# producer                 Nila Movie Makers
# link                                   NaN
# music
# Name: 0, dtype: object

# %%
data.loc[4]['link'][6:]
# Out:
# 'Pachai_Vilakku_(2020_film)'

# %%
# ! pip install wptools
# ! pip install wikipedia
import wptools
import wikipedia
# Out:
# Requirement already satisfied: wptools in /usr/local/lib/python3.6/dist-packages (0.4.17)
# Requirement already satisfied: html2text in /usr/local/lib/python3.6/dist-packages (from wptools) (2020.1.16)
# Requirement already satisfied: pycurl in /usr/local/lib/python3.6/dist-packages (from wptools) (7.43.0.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from wptools) (4.2.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from wptools) (2020.6.20)
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wikipedia) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)

# %%
def getmusicdir(movie,year):
  #print(wikipedia.search(movie))
  try:
    #title=wikipedia.page(movie).url[30:]
    #print(title+'|'+movie+" "+year+" tamil")
    so = wptools.page(movie).get_parse()
    infobox = so.data['infobox']
    if infobox is not None:
      if 'music' in infobox.keys():
        #print(infobox['music'])
        alphanumeric = ""
        for char in infobox['music']:
          if char.isalnum() or char is '.':
            alphanumeric += char
          elif char is ' ':
            alphanumeric += char
          else:
            alphanumeric += '-'
            
        music_dir=[]
        for part in alphanumeric.split('-'):
          if part is not '' and part is not ' ':
            music_dir.append(part)
        
        music_list=[]
        for dist in music_dir:
          if dist.lower().strip() not in ['br','\n','editor','nbsp','music director','small','songs','score','original songs','singer','background score','artist','artists'] and len(dist.lower().strip())>1:
            music_list.append(dist.strip())
        print(music_list)
        return music_list
      return []
    return []
  except:
    print("Exception");
    return []

# %%
xtest=getmusicdir('Asuraguru','2020')
xtest
# Out:
# en.wikipedia.org (parse) Asuraguru
# ['Simon K. King', 'Ganesh Raghavendra']
# en.wikipedia.org (imageinfo) File:Asuraguru poster.jpg
# Asuraguru (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Asuraguru...
#   infobox: <dict(17)> name, image, caption, director, producer, st...
#   pageid: 59489156
#   parsetree: <str(14737)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Asuraguru
#   wikibase: Q60533190
#   wikidata_url: https://www.wikidata.org/wiki/Q60533190
#   wikitext: <str(9545)> {{short description|2020 Indian Tamil-lang...
# }
# ['Simon K. King', 'Ganesh Raghavendra']

# %%
def tostr(arr):
  res=''
  if res is not None:
    for a in arr:
      res=res+a.strip()+','
    return res[:-1]
  return res

# %%
for index,row in data.iterrows():
  mlink=row['link']
  if mlink is not None:
    print(str(mlink).strip()[6:])
    dirs=getmusicdir(str(row['title']),str(row['year']))
    strdir=tostr(dirs)
    print(str(index)+' | '+strdir)
    data.at[index,'music']=strdir
# Out:
# Exception
# 0 |
# en.wikipedia.org (parse) Anantha Veedu
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Ayya Ullen Ayya
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) En Sangathu Aala Adichavan Evanada
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Kadhal Vizhigal
# Exception
# 1 |
#
# Exception
# 2 |
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Pachai Vilakku
# Exception
# 3 |
# Pachai_Vilakku_(2020_film)
# Pachai Vilakku (en) data
# {
#   pageid: 63405150
#   parsetree: <str(330)> <root>'''''Pachai Vilakku''''' (<template>...
#   requests: <list(1)> parse
#   title: Pachai Vilakku
#   wikibase: Q92789751
#   wikidata_url: https://www.wikidata.org/wiki/Q92789751
#   wikitext: <str(195)> '''''Pachai Vilakku''''' ({{trans|Green Lig...
# }
# en.wikipedia.org (parse) Pizhai
# 4 |
# Pizhai
# en.wikipedia.org (imageinfo) File:Pizhai poster.jpg
# Pizhai (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Pizhai po...
#   infobox: <dict(12)> name, image, director, producer, starring, m...
#   pageid: 63533110
#   parsetree: <str(6078)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Pizhai
#   wikibase: Q96399497
#   wikidata_url: https://www.wikidata.org/wiki/Q96399497
#   wikitext: <str(3748)> {{short description|2020 Tamil film}}{{Inf...
# }
# en.wikipedia.org (parse) Thedu
# ['FS Faizal']
# 5 | FS Faizal
# Thedu
# en.wikipedia.org (imageinfo) File:Thedu poster.jpg
# Thedu (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Thedu pos...
#   infobox: <dict(10)> name, image, director, producer, starring, m...
#   pageid: 63533598
#   parsetree: <str(4724)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Thedu
#   wikibase: Q96409733
#   wikidata_url: https://www.wikidata.org/wiki/Q96409733
#   wikitext: <str(2453)> {{short description|2020 Tamil film}}{{Mul...
# }
# en.wikipedia.org (parse) Thottu Vidum Thooram
# ['DJ Gopinath']
# 6 | DJ Gopinath
#
# Exception
# 7 |
# Darbar_(film)
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Darbar
# Darbar (en) data
# {
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/darbar
#   pageid: 522592
#   parsetree: <str(591)> <root><template><title>wiktionary</title><...
#   requests: <list(1)> parse
#   title: Darbar
#   wikibase: Q5222185
#   wikidata_url: https://www.wikidata.org/wiki/Q5222185
#   wikitext: <str(456)> {{wiktionary|darbar}}'''Darbar''' may refer...
# }
# en.wikipedia.org (parse) Pattas
# 8 |
# Pattas
# en.wikipedia.org (imageinfo) File:Pattas poster.jpg
# Pattas (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Pattas po...
#   infobox: <dict(17)> name, image, caption, director, producer, wr...
#   pageid: 61401923
#   parsetree: <str(31156)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Pattas
#   wikibase: Q82843367
#   wikidata_url: https://www.wikidata.org/wiki/Q82843367
#   wikitext: <str(22630)> {{About||the 2015 Telugu film of the same...
# }
# en.wikipedia.org (parse) Psycho
# ['Vivek', 'Mervin']
# 9 | Vivek,Mervin
# Psycho_(2019_film)
# Psycho (en) data
# {
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/psycho
#   pageid: 5365835
#   parsetree: <str(3794)> <root><template><title>wiktionary</title>...
#   requests: <list(1)> parse
#   title: Psycho
#   wikibase: Q246242
#   wikidata_url: https://www.wikidata.org/wiki/Q246242
#   wikitext: <str(3130)> {{wiktionary|psycho}}'''Psycho''' may refe...
# }
# en.wikipedia.org (parse) Rajavukku Check
# 10 |
# Rajavukku_Check
# en.wikipedia.org (imageinfo) File:Rajavukku Check.jpg
# Rajavukku Check (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Rajavukku...
#   infobox: <dict(16)> name, image, caption, director, producer, st...
#   pageid: 61532745
#   parsetree: <str(7966)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Rajavukku Check
#   wikibase: Q85795729
#   wikidata_url: https://www.wikidata.org/wiki/Q85795729
#   wikitext: <str(5242)> {{short description|2020 film directed by ...
# }
# en.wikipedia.org (parse) Taana
# ['Vinod Yajamanya']
# 11 | Vinod Yajamanya
# Taana_(film)
# Taana (en) data
# {
#   pageid: 44252930
#   parsetree: <str(459)> <root>'''Taana''' may refer to:*[[Thaana]]...
#   requests: <list(1)> parse
#   title: Taana
#   wikibase: Q27790694
#   wikidata_url: https://www.wikidata.org/wiki/Q27790694
#   wikitext: <str(367)> '''Taana''' may refer to:*[[Thaana]]  or Tā...
# }
# en.wikipedia.org (parse) Dagaalty
# 12 |
# Dagaalty
# en.wikipedia.org (imageinfo) File:Dagaalty poster.jpg
# Dagaalty (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dagaalty ...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 61097070
#   parsetree: <str(11427)> <root><comment>&lt;!-- Do not remove thi...
#   requests: <list(2)> parse, imageinfo
#   title: Dagaalty
#   wikibase: Q85755519
#   wikidata_url: https://www.wikidata.org/wiki/Q85755519
#   wikitext: <str(5810)> <!-- Do not remove this line! -->{{short d...
# }
# en.wikipedia.org (parse) Maayanadhi
# ['Vijay Narain']
# 13 | Vijay Narain
# Maayanadhi
# en.wikipedia.org (imageinfo) File:Maayanadhi.jpg
# Maayanadhi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Maayanadh...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 61878486
#   parsetree: <str(7207)> <root><template><title>About</title><part...
#   requests: <list(2)> parse, imageinfo
#   title: Maayanadhi
#   wikibase: Q85782926
#   wikidata_url: https://www.wikidata.org/wiki/Q85782926
#   wikitext: <str(4680)> {{About||the 2017 Malayalam film|Mayanadi}...
# }
# en.wikipedia.org (parse) Utraan
# ['Bhavatharini']
# 14 | Bhavatharini
# Utraan
# en.wikipedia.org (imageinfo) File:Utraan.jpg
# Utraan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Utraan.jp...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   pageid: 63547563
#   parsetree: <str(6861)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Utraan
#   wikibase: Q96413152
#   wikidata_url: https://www.wikidata.org/wiki/Q96413152
#   wikitext: <str(4469)> {{short description|2020 Tamil film}}{{Inf...
# }
# en.wikipedia.org (parse) Vanmurai
# ['N. R. Raghunanthan']
# 15 | N. R. Raghunanthan
# Vanmurai
# Cochin Shadhi at Chennai 03 (en) data
# {
#   infobox: <dict(14)> name, caption, director, producer, writer, s...
#   pageid: 63316821
#   parsetree: <str(4804)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Cochin Shadhi at Chennai 03
#   wikibase: Q96375187
#   wikidata_url: https://www.wikidata.org/wiki/Q96375187
#   wikitext: <str(2726)> {{Use dmy dates|date=July 2020}}{{Use Indi...
# }
# en.wikipedia.org (parse) Naadodigal 2
# ['Sunny Viswanath']
# 16 | Sunny Viswanath
# Naadodigal_2
# en.wikipedia.org (imageinfo) File:Naadodigal 2 Poster.jpg
# Naadodigal 2 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Naadodiga...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   pageid: 58829227
#   parsetree: <str(17380)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Naadodigal 2
#   wikibase: Q60737575
#   wikidata_url: https://www.wikidata.org/wiki/Q60737575
#   wikitext: <str(11050)> {{short description|2020 Indian Tamil-lan...
# }
# en.wikipedia.org (parse) Adavi
# ['Justin Prabhakaran']
# 17 | Justin Prabhakaran
# Adavi_(film)
# Adavi (en) data
# {
#   pageid: 24929037
#   parsetree: <str(409)> <root>'''Adavi''' may refer to:*[[Adavi, K...
#   requests: <list(1)> parse
#   title: Adavi
#   wikibase: Q4680899
#   wikidata_url: https://www.wikidata.org/wiki/Q4680899
#   wikitext: <str(306)> '''Adavi''' may refer to:*[[Adavi, Kerala]]...
# }
# en.wikipedia.org (parse) Pulikodi Devan
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Sandimuni
# 18 |
#
# Exception
# 19 |
# Sandimuni
# en.wikipedia.org (imageinfo) File:Sandimuni poster.jpg
# Sandimuni (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sandimuni...
#   infobox: <dict(14)> name, image, caption, director, producer, st...
#   pageid: 63385898
#   parsetree: <str(6243)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Sandimuni
#   wikibase: Q96404924
#   wikidata_url: https://www.wikidata.org/wiki/Q96404924
#   wikitext: <str(3585)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Seeru
# ['A K. Rishalsai']
# 20 | A K. Rishalsai
# Seeru
# en.wikipedia.org (imageinfo) File:Seeru poster.jpg
# Seeru (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Seeru pos...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 60037740
#   parsetree: <str(19598)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Seeru
#   wikibase: Q65075520
#   wikidata_url: https://www.wikidata.org/wiki/Q65075520
#   wikitext: <str(13747)> {{Use dmy dates|date=March 2019}}{{Use In...
# }
# en.wikipedia.org (parse) Vaanam Kottattum
# ['D. Imman']
# 21 | D. Imman
# Vaanam_Kottattum
# en.wikipedia.org (imageinfo) File:Vaanam Kottattum.jpg
# Vaanam Kottattum (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Vaanam Ko...
#   infobox: <dict(17)> name, image, caption, director, producer, sc...
#   pageid: 61628991
#   parsetree: <str(30745)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Vaanam Kottattum
#   wikibase: Q85847920
#   wikidata_url: https://www.wikidata.org/wiki/Q85847920
#   wikitext: <str(22601)> {{short description|2020 film by Dhana Se...
# }
# en.wikipedia.org (parse) Jasmine
# ['Sid Sriram', 'Sid Sriram', 'composer']
# 22 | Sid Sriram,Sid Sriram,composer
# en.wikipedia.org (imageinfo) File:Common Jasmine.jpg
# Jasmine (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Common Ja...
#   infobox: <dict(9)> image, image_caption, taxon, authority, type_...
#   iwlinks: <list(4)> https://en.wiktionary.org/wiki/Jasmine, https...
#   pageid: 98585
#   parsetree: <str(27315)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Jasmine
#   wikibase: Q82014
#   wikidata_url: https://www.wikidata.org/wiki/Q82014
#   wikitext: <str(19939)> {{short description|Species of plant}}{{a...
# }
# en.wikipedia.org (parse) Day Knight
# 23 |
#
# Exception
# 24 |
# Naan_Sirithaal
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Naan Sirithaal
# en.wikipedia.org (imageinfo) File:Naan Sirithal poster.jpg
# Naan Sirithal (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Naan Siri...
#   infobox: <dict(18)> name, image, caption, director, producer, ba...
#   pageid: 61993275
#   parsetree: <str(20329)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Naan Sirithal
#   wikibase: Q85846742
#   wikidata_url: https://www.wikidata.org/wiki/Q85846742
#   wikitext: <str(13889)> {{short description|2020 film directed by...
# }
# en.wikipedia.org (parse) Oh My Kadavule
# ['Hiphop Tamizha']
# 25 | Hiphop Tamizha
# Oh_My_Kadavule
# en.wikipedia.org (imageinfo) File:Oh My Kadavule poster.jpg
# Oh My Kadavule (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Oh My Kad...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 62815530
#   parsetree: <str(50951)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Oh My Kadavule
#   wikibase: Q85790351
#   wikidata_url: https://www.wikidata.org/wiki/Q85790351
#   wikitext: <str(34336)> {{Use dmy dates|date=February 2020}}{{Use...
# }
# en.wikipedia.org (parse) Baaram
# ['Leon James', 'composer', 'Leon James']
# 26 | Leon James,composer,Leon James
# Baaram
# en.wikipedia.org (imageinfo) File:Baaram poster.jpg
# Baaram (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Baaram po...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   pageid: 61482287
#   parsetree: <str(17121)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Baaram
#   wikibase: Q66475661
#   wikidata_url: https://www.wikidata.org/wiki/Q66475661
#   wikitext: <str(13363)> {{short description|Indian film}}{{Use dm...
# }
# en.wikipedia.org (parse) God Father
# 27 |
# God_Father_(2020_film)
# Godfather (en) data
# {
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/godfather
#   pageid: 411134
#   parsetree: <str(3670)> <root><template><title>redirect-distingui...
#   requests: <list(1)> parse
#   title: Godfather
#   wikibase: Q19284238
#   wikidata_url: https://www.wikidata.org/wiki/Q19284238
#   wikitext: <str(2891)> {{redirect-distinguish|God Father|God the ...
# }
# en.wikipedia.org (parse) Kutty Devathai
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Kanni Maadam
# 28 |
#
# Exception
# 29 |
# Kanni_Maadam
# en.wikipedia.org (imageinfo) File:Kanni Maadam.jpg
# Kanni Maadam (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Kanni Maa...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 63531217
#   parsetree: <str(7500)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Kanni Maadam
#   wikibase: Q96385335
#   wikidata_url: https://www.wikidata.org/wiki/Q96385335
#   wikitext: <str(4907)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Mafia: Chapter 1
# ['Hari Sai']
# 30 | Hari Sai
# Mafia:_Chapter_1
# en.wikipedia.org (imageinfo) File:Mafia Chapter 1 poster.jpg
# Mafia: Chapter 1 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Mafia Cha...
#   infobox: <dict(14)> name, image, director, producer, starring, m...
#   pageid: 61680732
#   parsetree: <str(19750)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Mafia: Chapter 1
#   wikibase: Q85846515
#   wikidata_url: https://www.wikidata.org/wiki/Q85846515
#   wikitext: <str(15142)> {{short description|Film directed by Kart...
# }
# en.wikipedia.org (parse) Meendum Oru Mariyathai
# ['Jakes Bejoy']
# 31 | Jakes Bejoy
# Meendum_Oru_Mariyathai
# en.wikipedia.org (imageinfo) File:Meendum Oru Mariyathai.jpg
# Meendum Oru Mariyathai (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Meendum O...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   pageid: 59526129
#   parsetree: <str(14543)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Meendum Oru Mariyathai
#   wikibase: Q60738093
#   wikidata_url: https://www.wikidata.org/wiki/Q60738093
#   wikitext: <str(7263)> {{short description|Film directed by P. Bh...
# }
# en.wikipedia.org (parse) Draupathi
# ['N. R. Raghunanthan', 'Sharran Surya', 'Yuvan Shankar Raja', 'Sabesh', 'Murali']
# 32 | N. R. Raghunanthan,Sharran Surya,Yuvan Shankar Raja,Sabesh,Murali
# Draupathi_(2020_film)
# en.wikipedia.org (imageinfo) File:Raja Ravi Varma, Pleasing.jpg
# Draupadi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Raja Ravi...
#   infobox: <dict(13)> image, alt, caption, spouse, siblings, child...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:D...
#   pageid: 381878
#   parsetree: <str(54751)> <root><template><title>other uses</title...
#   requests: <list(2)> parse, imageinfo
#   title: Draupadi
#   wikibase: Q1057886
#   wikidata_url: https://www.wikidata.org/wiki/Q1057886
#   wikitext: <str(45476)> {{other uses}}{{short description|Main fe...
# }
# en.wikipedia.org (parse) Galtha
# 33 |
# Galtha
# en.wikipedia.org (imageinfo) File:Galtha.jpg
# Galtha (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Galtha.jp...
#   infobox: <dict(14)> name, image, caption, director, producer, st...
#   pageid: 63174948
#   parsetree: <str(5483)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Galtha
#   wikibase: Q96379050
#   wikidata_url: https://www.wikidata.org/wiki/Q96379050
#   wikitext: <str(3451)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Irumbu Manithan
# ['K Jai Krish']
# 34 | K Jai Krish
# Irumbu_Manithan
# en.wikipedia.org (imageinfo) File:Irumbu Manithan.jpg
# Irumbu Manithan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Irumbu Ma...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 63454720
#   parsetree: <str(5645)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Irumbu Manithan
#   wikibase: Q96382883
#   wikidata_url: https://www.wikidata.org/wiki/Q96382883
#   wikitext: <str(3325)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Kadalil Kattumaramai
# ['K.S.Manoj']
# 35 | K.S.Manoj
#
# Exception
# 36 |
# Kannum_Kannum_Kollaiyadithaal
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Kannum Kannum Kollaiyadithaal
# en.wikipedia.org (imageinfo) File:Kannum Kannum Kollaiyadithaal.jpg
# Kannum Kannum Kollaiyadithaal (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Kannum Ka...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 56440839
#   parsetree: <str(44985)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Kannum Kannum Kollaiyadithaal
#   wikibase: Q48671740
#   wikidata_url: https://www.wikidata.org/wiki/Q48671740
#   wikitext: <str(32875)> {{Use dmy dates|date = March 2018}}{{Use ...
# }
# en.wikipedia.org (parse) College Kumar
# ['Soundtrack', 'Masala Coffee', 'Harshavardhan Rameshwar']
# 37 | Soundtrack,Masala Coffee,Harshavardhan Rameshwar
# College_Kumar_(2020_film)
# en.wikipedia.org (imageinfo) File:College Kumar.jpg
# College Kumar (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:College K...
#   infobox: <dict(14)> name, image, director, producer, writer, sta...
#   pageid: 55723823
#   parsetree: <str(12145)> <root><template><title>for</title><part>...
#   requests: <list(2)> parse, imageinfo
#   title: College Kumar
#   wikibase: Q42955726
#   wikidata_url: https://www.wikidata.org/wiki/Q42955726
#   wikitext: <str(5718)> {{for|the 2020 film|College Kumar (2020 fi...
# }
# en.wikipedia.org (parse) Ettuthikkum Para
# ['Arjun Janya']
# 38 | Arjun Janya
# Ettuthikkum_Para
# en.wikipedia.org (imageinfo) File:Ettuthikkum Para.jpg
# Ettuthikkum Para (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ettuthikk...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 63529367
#   parsetree: <str(6348)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Ettuthikkum Para
#   wikibase: Q96377434
#   wikidata_url: https://www.wikidata.org/wiki/Q96377434
#   wikitext: <str(3947)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Gypsy
# ['M. S. Sreekanth']
# 39 | M. S. Sreekanth
# Gypsy_(2020_film)
# Romani people (en) data
# {
#   image: <list(0)>
#   infobox: <dict(88)> group, image, flag, flag_caption, pop, regio...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 26152
#   parsetree: <str(250831)> <root><template><title>Distinguish </ti...
#   requests: <list(1)> parse
#   title: Romani people
#   wikibase: Q8060
#   wikidata_url: https://www.wikidata.org/wiki/Q8060
#   wikitext: <str(181356)> {{Distinguish |text=[[Romanians]], an un...
# }
# en.wikipedia.org (parse) Indha Nilai Maarum
# 40 |
# Indha_Nilai_Maarum
# en.wikipedia.org (imageinfo) File:Indha Nilai Maarum poster.jpg
# Indha Nilai Maarum (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Indha Nil...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 57197740
#   parsetree: <str(6687)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Indha Nilai Maarum
#   wikibase: Q96382030
#   wikidata_url: https://www.wikidata.org/wiki/Q96382030
#   wikitext: <str(3928)> {{short description|2020 film}}{{Use dmy d...
# }
# en.wikipedia.org (parse) Velvet Nagaram
# ['Allen Sebastian', 'Arunkanth V']
# 41 | Allen Sebastian,Arunkanth V
# Velvet_Nagaram
# en.wikipedia.org (imageinfo) File:Velvet Nagaram film poster.jpg
# Velvet Nagaram (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Velvet Na...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 59449597
#   parsetree: <str(7159)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Velvet Nagaram
#   wikibase: Q60737835
#   wikidata_url: https://www.wikidata.org/wiki/Q60737835
#   wikitext: <str(4716)> {{short description|2020 Indian Tamil lang...
# }
# en.wikipedia.org (parse) Asuraguru
# ['Achu Rajamani', 'Saran Raghavan']
# 42 | Achu Rajamani,Saran Raghavan
# Asuraguru
# en.wikipedia.org (imageinfo) File:Asuraguru poster.jpg
# Asuraguru (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Asuraguru...
#   infobox: <dict(17)> name, image, caption, director, producer, st...
#   pageid: 59489156
#   parsetree: <str(14737)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Asuraguru
#   wikibase: Q60533190
#   wikidata_url: https://www.wikidata.org/wiki/Q60533190
#   wikitext: <str(9545)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Dharala Prabhu
# ['Simon K. King', 'Ganesh Raghavendra']
# 43 | Simon K. King,Ganesh Raghavendra
# Dharala_Prabhu
# en.wikipedia.org (imageinfo) File:Dharala Prabhu.jpg
# Dharala Prabhu (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dharala P...
#   infobox: <dict(17)> name, image, caption, director, producer, sc...
#   pageid: 63362029
#   parsetree: <str(20274)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Dharala Prabhu
#   wikibase: Q96219243
#   wikidata_url: https://www.wikidata.org/wiki/Q96219243
#   wikitext: <str(11869)> {{Use dmy dates|date = March 2020}}{{Use ...
# }
# en.wikipedia.org (parse) Kayiru
# ['Anirudh Ravichander', 'Sean Roldan', 'Vivek', 'Mervin', 'Inno Genga', 'Madley Blues', 'Bharath Shankar', 'Kaber Vasuki', 'Oorka']
# 44 | Anirudh Ravichander,Sean Roldan,Vivek,Mervin,Inno Genga,Madley Blues,Bharath Shankar,Kaber Vasuki,Oorka
#
# Exception
# 45 |
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Thanchamada Nee Yenakku
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Walter
# Exception
# 46 |
# Walter_(2020_film)
# Walter (en) data
# {
#   iwlinks: <list(2)> https://en.wiktionary.org/wiki/Walter, https:...
#   pageid: 17925623
#   parsetree: <str(2122)> <root><template><title>wiktionary</title>...
#   requests: <list(1)> parse
#   title: Walter
#   wikibase: Q246836
#   wikidata_url: https://www.wikidata.org/wiki/Q246836
#   wikitext: <str(1639)> {{wiktionary|Walter|walter}}'''Walter''' m...
# }
# en.wikipedia.org (parse) Sethum Aayiram Pon
# 47 |
# Sethum_Aayiram_Pon
# en.wikipedia.org (imageinfo) File:Sethum Aayiram Pon poster.jpg
# Sethum Aayiram Pon (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sethum Aa...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 63549190
#   parsetree: <str(9067)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Sethum Aayiram Pon
#   wikibase: Q92063713
#   wikidata_url: https://www.wikidata.org/wiki/Q92063713
#   wikitext: <str(6239)> {{short description|2019 Tamil film}}{{Inf...
# }
# en.wikipedia.org (parse) Ponmagal Vandhal
# ['Shamanth Nag']
# 48 | Shamanth Nag
# Ponmagal_Vandhal
# en.wikipedia.org (imageinfo) File:Ponmagal Vandhal.jpg
# Ponmagal Vandhal (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ponmagal ...
#   infobox: <dict(15)> name, image, caption, director, producer, st...
#   pageid: 63763531
#   parsetree: <str(34603)> <root><template><title>redirect</title><...
#   requests: <list(2)> parse, imageinfo
#   title: Ponmagal Vandhal
#   wikibase: Q95716755
#   wikidata_url: https://www.wikidata.org/wiki/Q95716755
#   wikitext: <str(27367)> {{redirect|Ponmagal Vanthal|the TV series...
# }
# en.wikipedia.org (parse) Mamakiki
# ['Govind Vasantha']
# 49 | Govind Vasantha
# Mamakiki
# en.wikipedia.org (imageinfo) File:MamaKiki poster.jpg
# Mamakiki (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:MamaKiki ...
#   infobox: <dict(13)> name, image, caption, director, producer, st...
#   pageid: 64154667
#   parsetree: <str(5932)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Mamakiki
#   wikibase: Q96391713
#   wikidata_url: https://www.wikidata.org/wiki/Q96391713
#   wikitext: <str(3327)> {{Use dmy dates|date=July 2020}}{{Use Indi...
# }
# en.wikipedia.org (parse) Penguin
# ['Jakes Bejoy', 'Vishal Chandrasekhar', 'M. S. Jones', 'Kalacharan', 'Surya Prasad']
# 50 | Jakes Bejoy,Vishal Chandrasekhar,M. S. Jones,Kalacharan,Surya Prasad
# Penguin_(film)
# en.wikipedia.org (imageinfo) File:South Shetland-2016-Deception I...
# Penguin (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:South She...
#   infobox: <dict(11)> name, fossil_range, image, image_caption, pa...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 23878
#   parsetree: <str(104385)> <root><template><title>pp-move-indef</t...
#   requests: <list(2)> parse, imageinfo
#   title: Penguin
#   wikibase: Q9147
#   wikidata_url: https://www.wikidata.org/wiki/Q9147
#   wikitext: <str(84092)> {{pp-move-indef}}{{short description|Fami...
# }
# en.wikipedia.org (parse) Yaadhumagi Nindraai
# 51 |
# Yaadhumagi_Nindraai
# en.wikipedia.org (imageinfo) File:Yaadhumagi Nindraai.jpg
# Yaadhumagi Nindraai (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Yaadhumag...
#   infobox: <dict(14)> name, image, caption, director, producer, st...
#   pageid: 64390895
#   parsetree: <str(5156)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Yaadhumagi Nindraai
#   wikibase: Q97354390
#   wikidata_url: https://www.wikidata.org/wiki/Q97354390
#   wikitext: <str(2969)> {{short description|2020 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Cocktail
# ['Ashwin Vinayagamoorthy', 'Achu Rajamani']
# 52 | Ashwin Vinayagamoorthy,Achu Rajamani
# Cocktail_(2020_film)
# Cocktail (en) data
# {
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 7599
#   parsetree: <str(18312)> <root><template><title>About</title><par...
#   requests: <list(1)> parse
#   title: Cocktail
#   wikibase: Q134768
#   wikidata_url: https://www.wikidata.org/wiki/Q134768
#   wikitext: <str(14575)> {{About|a mixed drink containing alcohol|...
# }
# en.wikipedia.org (parse) Danny
# 53 |
# Danny_(2020_film)
# Danny (en) data
# {
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/Danny
#   pageid: 2689102
#   parsetree: <str(7579)> <root><template><title>other uses</title>...
#   requests: <list(1)> parse
#   title: Danny
#   wikibase: Q17863942
#   wikidata_url: https://www.wikidata.org/wiki/Q17863942
#   wikitext: <str(7013)> {{other uses}}{{Wiktionary|Danny}}'''Danny...
# }
# en.wikipedia.org (parse) Lock Up
# 54 |
# Lock_Up_(2020_film)
# Lock up (en) data
# {
#   iwlinks: <list(2)> https://en.wiktionary.org/wiki/lock_up, https...
#   pageid: 4415717
#   parsetree: <str(2140)> <root><template><title>wiktionarypar</tit...
#   requests: <list(1)> parse
#   title: Lock up
#   wikibase: Q3464388
#   wikidata_url: https://www.wikidata.org/wiki/Q3464388
#   wikitext: <str(1727)> {{wiktionarypar|lock up|lockup}}'''Lock up...
# }
# en.wikipedia.org (parse) 4 January
# 55 |
# January 4 (en) data
# {
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 15982
#   parsetree: <str(107239)> <root><template><title>pp-pc1</title></...
#   requests: <list(1)> parse
#   title: January 4
#   wikibase: Q2168
#   wikidata_url: https://www.wikidata.org/wiki/Q2168
#   wikitext: <str(89317)> {{pp-pc1}}{{pp-move-indef}}{{calendar}}{{...
# }
# en.wikipedia.org (parse) Devakottai Kadhal
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Maanik
# 56 |
#
# Exception
# 57 |
# Maanik
# en.wikipedia.org (imageinfo) File:Maanik poster.jpg
# Maanik (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Maanik po...
#   infobox: <dict(13)> name, image, caption, director, producer, st...
#   pageid: 51454901
#   parsetree: <str(8375)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Maanik
#   wikibase: Q27959285
#   wikidata_url: https://www.wikidata.org/wiki/Q27959285
#   wikitext: <str(5129)> {{Use dmy dates|date=February 2017}}{{Use ...
# }
# en.wikipedia.org (parse) Sigai
# ['Dharan Kumar']
# 58 | Dharan Kumar
# Sigai
# en.wikipedia.org (imageinfo) File:Sigai poster.jpg
# Sigai (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sigai pos...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 54719895
#   parsetree: <str(9209)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Sigai
#   wikibase: Q48672463
#   wikidata_url: https://www.wikidata.org/wiki/Q48672463
#   wikitext: <str(6572)> {{short description|2019 film}}{{Use dmy d...
# }
# en.wikipedia.org (parse) Petta
# ['Ron Ethan Yohann']
# 59 | Ron Ethan Yohann
# Petta_(film)
# Petta (en) data
# {
#   pageid: 31970382
#   parsetree: <str(860)> <root>'''Petta''' may refer to:<h level="2...
#   requests: <list(1)> parse
#   title: Petta
#   wikibase: Q3901134
#   wikidata_url: https://www.wikidata.org/wiki/Q3901134
#   wikitext: <str(688)> '''Petta''' may refer to:==People==* [[Bobb...
# }
# en.wikipedia.org (parse) Viswasam
# 60 |
# Viswasam
# en.wikipedia.org (imageinfo) File:Viswasam poster.jpg
# Viswasam (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Viswasam ...
#   infobox: <dict(19)> name, image, caption, director, producer, wr...
#   pageid: 56285089
#   parsetree: <str(36997)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Viswasam
#   wikibase: Q47530517
#   wikidata_url: https://www.wikidata.org/wiki/Q47530517
#   wikitext: <str(25617)> {{short description|2019 film directed by...
# }
# en.wikipedia.org (parse) Charlie Chaplin 2
# ['D. Imman']
# 61 | D. Imman
# Charlie_Chaplin_2
# en.wikipedia.org (imageinfo) File:Charlie Chaplin 2 film 2019.jpg
# Charlie Chaplin 2 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Charlie C...
#   infobox: <dict(14)> name, image, director, producer, writer, sta...
#   pageid: 59335605
#   parsetree: <str(10831)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Charlie Chaplin 2
#   wikibase: Q60737714
#   wikidata_url: https://www.wikidata.org/wiki/Q60737714
#   wikitext: <str(7563)> {{short description|2019 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Kuthoosi
# ['Amresh Ganesh']
# 62 | Amresh Ganesh
# Kuthoosi
# en.wikipedia.org (imageinfo) File:Kuthoosi poster.jpg
# Kuthoosi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Kuthoosi ...
#   infobox: <dict(12)> name, image, caption, director, writer, star...
#   pageid: 59811665
#   parsetree: <str(9619)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Kuthoosi
#   wikibase: Q64768086
#   wikidata_url: https://www.wikidata.org/wiki/Q64768086
#   wikitext: <str(4912)> {{Use dmy dates|date=July 2020}}{{Use Indi...
# }
# en.wikipedia.org (parse) Simba
# ['Kannan', 'N. Kannan']
# 63 | Kannan,N. Kannan
# Simba_(2019_film)
# en.wikipedia.org (imageinfo) File:Simba ( Disney character - adult).png
# Simba (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Simba ( D...
#   infobox: <dict(13)> colour, name, image, caption, first, creator...
#   pageid: 983014
#   parsetree: <str(87373)> <root><template><title>Other uses</title...
#   requests: <list(2)> parse, imageinfo
#   title: Simba
#   wikibase: Q1649583
#   wikidata_url: https://www.wikidata.org/wiki/Q1649583
#   wikitext: <str(73637)> {{Other uses|Simba (disambiguation)}}{{Go...
# }
# en.wikipedia.org (parse) Pei Ellam Paavam
# 64 |
#
# Exception
# 65 |
# Peranbu
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Peranbu
# en.wikipedia.org (imageinfo) File:Peranbu poster.jpg
# Peranbu (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Peranbu p...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 48964261
#   parsetree: <str(29372)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Peranbu
#   wikibase: Q21998248
#   wikidata_url: https://www.wikidata.org/wiki/Q21998248
#   wikitext: <str(21567)> {{short description|2019 Indian Tamil-lan...
# }
# en.wikipedia.org (parse) Sagaa
# ['Yuvan Shankar Raja']
# 66 | Yuvan Shankar Raja
# Sagaa
# en.wikipedia.org (imageinfo) File:Sagaa poster.jpg
# Sagaa (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sagaa pos...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 50498371
#   parsetree: <str(13694)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Sagaa
#   wikibase: Q24905461
#   wikidata_url: https://www.wikidata.org/wiki/Q24905461
#   wikitext: <str(8162)> {{Use dmy dates|date=March 2019}}{{Use Ind...
# }
# en.wikipedia.org (parse) Sarvam Thaala Mayam
# ['Shabir']
# 67 | Shabir
# Sarvam_Thaala_Mayam
# en.wikipedia.org (imageinfo) File:Sarvam Thaala Mayam Poster.jpg
# Sarvam Thaala Mayam (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sarvam Th...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 56278341
#   parsetree: <str(14835)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Sarvam Thaala Mayam
#   wikibase: Q48671528
#   wikidata_url: https://www.wikidata.org/wiki/Q48671528
#   wikitext: <str(10654)> {{short description|2019 Tamil-language m...
# }
# en.wikipedia.org (parse) Vantha Rajavathaan Varuven
# ['A. R. Rahman', 'Rajiv Menon', 'One song', 'A. R. Rahman', 'Qutub', 'Kripa']
# 68 | A. R. Rahman,Rajiv Menon,One song,A. R. Rahman,Qutub,Kripa
# Vantha_Rajavathaan_Varuven
# en.wikipedia.org (imageinfo) File:Vantha Rajavathaan Varuven.jpg
# Vantha Rajavathaan Varuven (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Vantha Ra...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 59020411
#   parsetree: <str(16944)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Vantha Rajavathaan Varuven
#   wikibase: Q60737613
#   wikidata_url: https://www.wikidata.org/wiki/Q60737613
#   wikitext: <str(11119)> {{short description|2019 Indian Tamil-lan...
# }
# en.wikipedia.org (parse) Dhilluku Dhuddu 2
# ['Hiphop Tamizha']
# 69 | Hiphop Tamizha
# Dhilluku_Dhuddu_2
# en.wikipedia.org (imageinfo) File:Dhilluku Dhuddu 2 poster.jpg
# Dhilluku Dhuddu 2 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dhilluku ...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 59336681
#   parsetree: <str(13239)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Dhilluku Dhuddu 2
#   wikibase: Q59725655
#   wikidata_url: https://www.wikidata.org/wiki/Q59725655
#   wikitext: <str(8969)> {{short description|2019 Indian Tamil-lang...
# }
# en.wikipedia.org (parse) Podhu Nalan Karudhi
# ['Shabir']
# 70 | Shabir
# Podhu_Nalan_Karudhi
# en.wikipedia.org (imageinfo) File:Podhu Nalan Karudhi poster.jpg
# Podhu Nalan Karudhi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Podhu Nal...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   pageid: 51330388
#   parsetree: <str(4962)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Podhu Nalan Karudhi
#   wikibase: Q27958454
#   wikidata_url: https://www.wikidata.org/wiki/Q27958454
#   wikitext: <str(2592)> {{Use dmy dates|date=January 2016}}{{Use I...
# }
# en.wikipedia.org (parse) Avathara Vettai
# ['A. Hariganesh']
# 71 | A. Hariganesh
#
# Exception
# 72 |
# Nethraa
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Nethraa
# en.wikipedia.org (imageinfo) File:Nethraa poster.jpg
# Nethraa (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Nethraa p...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 51503306
#   parsetree: <str(7498)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Nethraa
#   wikibase: Q27959306
#   wikidata_url: https://www.wikidata.org/wiki/Q27959306
#   wikitext: <str(4723)> {{Use dmy dates|date=February 2017}}{{Use ...
# }
# en.wikipedia.org (parse) Urangapuli
# ['Srikanth Deva']
# 73 | Srikanth Deva
#
# Exception
# 74 |
# Vaandu
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Vaandu
# en.wikipedia.org (imageinfo) File:Vaandu poster.jpg
# Vaandu (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Vaandu po...
#   infobox: <dict(11)> name, image, caption, director, producer, st...
#   pageid: 64427580
#   parsetree: <str(7650)> <root><template><title>Infobox film</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Vaandu
#   wikibase: Q97188700
#   wikidata_url: https://www.wikidata.org/wiki/Q97188700
#   wikitext: <str(3854)> {{Infobox film| name           = Vaandu| i...
# }
# en.wikipedia.org (parse) Kalavu
# ['A. R. Neshan']
# 75 | A. R. Neshan
# Kalavu_(2019_film)
# Kalavu (en) data
# {
#   infobox: <dict(12)> name, director, producer, writer, starring, ...
#   pageid: 41421089
#   parsetree: <str(4138)> <root><template><title>About</title><part...
#   requests: <list(1)> parse
#   title: Kalavu
#   wikibase: Q16249973
#   wikidata_url: https://www.wikidata.org/wiki/Q16249973
#   wikitext: <str(1967)> {{About||the 2019 film|Kalavu (2019 film)}...
# }
# en.wikipedia.org (parse) Dev
# ['S Chinna']
# 76 | S Chinna
# Dev_(2019_film)
# Dev (en) data
# {
#   pageid: 1145442
#   parsetree: <str(2456)> <root><template><title>TOC right</title><...
#   requests: <list(1)> parse
#   title: Dev
#   wikibase: Q408125
#   wikidata_url: https://www.wikidata.org/wiki/Q408125
#   wikitext: <str(2037)> {{TOC right}}==People=====Single names===*...
# }
# en.wikipedia.org (parse) Chithiram Pesuthadi 2
# 77 |
# Chithiram_Pesuthadi_2
# en.wikipedia.org (imageinfo) File:Chithiram Pesuthadi 2 poster.jpg
# Chithiram Pesuthadi 2 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Chithiram...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 40677277
#   parsetree: <str(13057)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Chithiram Pesuthadi 2
#   wikibase: Q16254928
#   wikidata_url: https://www.wikidata.org/wiki/Q16254928
#   wikitext: <str(9940)> {{short description|2019 film by Rajan Mad...
# }
# en.wikipedia.org (parse) Goko Mako
# ['Sajan Madhav']
# 78 | Sajan Madhav
# Goko_Mako
# en.wikipedia.org (imageinfo) File:Goko Mako poster.jpg
# Goko Mako (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Goko Mako...
#   infobox: <dict(18)> name, image, caption, director, producer, wr...
#   pageid: 63113846
#   parsetree: <str(5913)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Goko Mako
#   wikibase: Q85763856
#   wikidata_url: https://www.wikidata.org/wiki/Q85763856
#   wikitext: <str(3573)> {{Use dmy dates|date=July 2020}}{{Use Indi...
# }
# en.wikipedia.org (parse) Kadhal Mattum Vena
# ['Arunkanth']
# 79 | Arunkanth
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) To Let
# Exception
# 80 |
# To_Let_(film)
# en.wikipedia.org (imageinfo) File:Xavier Rudd - To Let.jpg
# To Let (en) data
# {
#   image: <list(1)> {'kind': 'parse-cover', 'file': 'File:Xavier Ru...
#   infobox: <dict(10)> name, type, artist, cover, released, genre, ...
#   pageid: 25002022
#   parsetree: <str(5617)> <root><template><title>About</title><part...
#   requests: <list(2)> parse, imageinfo
#   title: To Let
#   wikibase: Q3992056
#   wikidata_url: https://www.wikidata.org/wiki/Q3992056
#   wikitext: <str(2206)> {{About||the 2017 Indian film|To Let (film...
# }
# en.wikipedia.org (parse) Arandavanuku Irundadhellam Pei
# 81 |
#
# Exception
# 82 |
# Kanne_Kalaimaane
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Kanne Kalaimaane
# en.wikipedia.org (imageinfo) File:Kanne Kalaimaane.jpg
# Kanne Kalaimaane (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Kanne Kal...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   pageid: 56852458
#   parsetree: <str(13504)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Kanne Kalaimaane
#   wikibase: Q50819351
#   wikidata_url: https://www.wikidata.org/wiki/Q50819351
#   wikitext: <str(8789)> {{short description|2019 film by Seenu Ram...
# }
# en.wikipedia.org (parse) LKG
# ['Yuvan Shankar Raja']
# 83 | Yuvan Shankar Raja
# LKG_(film)
# LKG (en) data
# {
#   pageid: 26713596
#   parsetree: <str(269)> <root>'''LKG''' may refer to:* [[LKG (film...
#   requests: <list(1)> parse
#   title: LKG
#   wikibase: Q1798166
#   wikidata_url: https://www.wikidata.org/wiki/Q1798166
#   wikitext: <str(210)> '''LKG''' may refer to:* [[LKG (film)|''LKG...
# }
# en.wikipedia.org (parse) Pettikadai
# 84 |
# Pettikadai
# en.wikipedia.org (imageinfo) File:Samuthirakani-pettikadai-movie-...
# Pettikadai (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Samuthira...
#   infobox: <dict(13)> name, image, caption, director, writer, star...
#   pageid: 60024626
#   parsetree: <str(6381)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Pettikadai
#   wikibase: Q64768300
#   wikidata_url: https://www.wikidata.org/wiki/Q64768300
#   wikitext: <str(4741)> {{Use dmy dates|date=March 2019}}{{Use Ind...
# }
# en.wikipedia.org (parse) 90ML
# ['Mariya Manohar']
# 85 | Mariya Manohar
# 90ML_(2019_Tamil_film)
# 90ml (en) data
# {
#   pageid: 61543334
#   parsetree: <str(278)> <root>'''90ML''' may refer to:* [[90 ML (2...
#   requests: <list(1)> parse
#   title: 90ml
#   wikibase: Q93187721
#   wikidata_url: https://www.wikidata.org/wiki/Q93187721
#   wikitext: <str(219)> '''90ML''' may refer to:* [[90 ML (2019 Tam...
# }
# en.wikipedia.org (parse) Adadae
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Dha Dha 87
# 86 |
#
# Exception
# 87 |
# Dha_Dha_87
# en.wikipedia.org (imageinfo) File:Dha Dha 87.jpg
# Dha Dha 87 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dha Dha 8...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 59660616
#   parsetree: <str(13334)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Dha Dha 87
#   wikibase: Q60738566
#   wikidata_url: https://www.wikidata.org/wiki/Q60738566
#   wikitext: <str(7387)> {{Use dmy dates|date=March 2019}}{{Use Ind...
# }
# en.wikipedia.org (parse) Pirivadhillai
# ['Leander Lee Marty']
# 88 | Leander Lee Marty
#
# Exception
# 89 |
# Thadam
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# ...
#   title: Neethana Avan
#   wikibase: Q77894408
#   wikidata_url: https://www.wikidata.org/wiki/Q77894408
#   wikitext: <str(6973)> {{Use Indian English|date=November 2019}}{...
# }
# en.wikipedia.org (parse) Chithira Poove
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Mynaa
# ['V. Thashi']
# 1677 | V. Thashi
# ex.php?title=Chithira_Poove&action=edit&redlink=1
# Exception
# 1678 |
# Mynaa
# en.wikipedia.org (imageinfo) File:Mynaa poster.jpg
# Mynaa (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Mynaa pos...
#   infobox: <dict(19)> name, image, caption, native_name, director,...
#   pageid: 29449838
#   parsetree: <str(24874)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Mynaa
#   wikibase: Q6947810
#   wikidata_url: https://www.wikidata.org/wiki/Q6947810
#   wikitext: <str(16119)> {{short description|2010 film by Prabhu S...
# }
# en.wikipedia.org (parse) Uthama Puthiran
# ['D. Imman']
# 1679 | D. Imman
# Uthamaputhiran_(2010_film)
# Uthama Puthiran (en) data
# {
#   pageid: 25548186
#   parsetree: <str(475)> <root>'''Uthama Puthiran''' may refer to:*...
#   requests: <list(1)> parse
#   title: Uthama Puthiran
#   wikibase: Q7902686
#   wikidata_url: https://www.wikidata.org/wiki/Q7902686
#   wikitext: <str(416)> '''Uthama Puthiran''' may refer to:* [[Utha...
# }
# en.wikipedia.org (parse) Va
# 1680 |
# Va_(film)
# VA (en) data
# {
#   iwlinks: <list(2)> https://en.wiktionary.org/wiki/VA, https://en...
#   pageid: 224184
#   parsetree: <str(4114)> <root><template><title>Wiktionary</title>...
#   requests: <list(1)> parse
#   title: VA
#   wikibase: Q219297
#   wikidata_url: https://www.wikidata.org/wiki/Q219297
#   wikitext: <str(3560)> {{Wiktionary|VA|Va}}'''VA''', '''Va''' and...
# }
# en.wikipedia.org (parse) Vallakottai
# 1681 |
# Vallakottai_(film)
# Vallakottai (en) data
# {
#   infobox: <dict(24)> name, settlement_type, image_skyline, pushpi...
#   pageid: 11650554
#   parsetree: <str(6548)> <root><template><title>unsourced</title><...
#   requests: <list(1)> parse
#   title: Vallakottai
#   wikibase: Q12988818
#   wikidata_url: https://www.wikidata.org/wiki/Q12988818
#   wikitext: <str(2852)> {{unsourced|date=August 2018}}{{Use dmy da...
# }
# en.wikipedia.org (parse) Magizhchi
# 1682 |
# Magizhchi
# Magizhchi (en) data
# {
#   infobox: <dict(12)> name, director, producer, screenplay, based_...
#   pageid: 25223371
#   parsetree: <str(8184)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Magizhchi
#   wikibase: Q16251055
#   wikidata_url: https://www.wikidata.org/wiki/Q16251055
#   wikitext: <str(4308)> {{Use dmy dates|date=October 2015}}{{Use I...
# }
# en.wikipedia.org (parse) Mandhira Punnagai
# ['Vidyasagar', 'Vidyasagar']
# 1683 | Vidyasagar,Vidyasagar
# Mandhira_Punnagai_(2010_film)
# Mandhira Punnagai (en) data
# {
#   pageid: 56671394
#   parsetree: <str(303)> <root>'''''Mandhira Punnagai''''' (<templa...
#   requests: <list(1)> parse
#   title: Mandhira Punnagai
#   wikibase: Q50099401
#   wikidata_url: https://www.wikidata.org/wiki/Q50099401
#   wikitext: <str(168)> '''''Mandhira Punnagai''''' ({{literal tran...
# }
# en.wikipedia.org (parse) Nagaram Marupakkam
# 1684 |
# Nagaram_Marupakkam
# en.wikipedia.org (imageinfo) File:Nagaram Marupakkam.jpg
# Nagaram Marupakkam (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Nagaram M...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 29510479
#   parsetree: <str(11295)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Nagaram Marupakkam
#   wikibase: Q6958538
#   wikidata_url: https://www.wikidata.org/wiki/Q6958538
#   wikitext: <str(6394)> {{Use dmy dates|date=November 2015}}{{Use ...
# }
# en.wikipedia.org (parse) Kanimozhi
# ['Thaman']
# 1685 | Thaman
# Kanimozhi_(film)
# en.wikipedia.org (imageinfo) File:MPKanimozhi.jpg
# Kanimozhi Karunanidhi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:MPKanimoz...
#   infobox: <dict(41)> name, image, caption, office, term_start, pr...
#   pageid: 11168721
#   parsetree: <str(23219)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Kanimozhi Karunanidhi
#   wikibase: Q467231
#   wikidata_url: https://www.wikidata.org/wiki/Q467231
#   wikitext: <str(16429)> {{short description|Indian politician}}{{...
# }
# en.wikipedia.org (parse) Nandalala
# 1686 |
# Nandalala
# en.wikipedia.org (imageinfo) File:nandalala.jpg
# Nandalala (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:nandalala...
#   infobox: <dict(16)> name, image, director, producer, writer, bas...
#   pageid: 16490753
#   parsetree: <str(27486)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Nandalala
#   wikibase: Q6963166
#   wikidata_url: https://www.wikidata.org/wiki/Q6963166
#   wikitext: <str(19462)> {{Use dmy dates|date=November 2015}}{{Use...
# }
# en.wikipedia.org (parse) Chikku Bukku
# ['Ilayaraaja']
# 1687 | Ilayaraaja
# Chikku_Bukku
# en.wikipedia.org (imageinfo) File:Chikkubukku.jpg
# Chikku Bukku (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Chikkubuk...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 21606896
#   parsetree: <str(17407)> <root><template><title>EngvarB</title><p...
#   requests: <list(2)> parse, imageinfo
#   title: Chikku Bukku
#   wikibase: Q5097465
#   wikidata_url: https://www.wikidata.org/wiki/Q5097465
#   wikitext: <str(13091)> {{EngvarB|date=February 2014}}{{Use dmy d...
# }
# en.wikipedia.org (parse) Tha
# ['Colonial Cousins', 'Pravin Mani']
# 1688 | Colonial Cousins,Pravin Mani
# Tha_(film)
# THA (en) data
# {
#   pageid: 2201164
#   parsetree: <str(638)> <root>'''Tha''' or '''THA''' may refer to:...
#   requests: <list(1)> parse
#   title: THA
#   wikibase: Q424876
#   wikidata_url: https://www.wikidata.org/wiki/Q424876
#   wikitext: <str(579)> '''Tha''' or '''THA''' may refer to:* [[Tha...
# }
# en.wikipedia.org (parse) Agam Puram
# 1689 |
# Agam_Puram
# en.wikipedia.org (imageinfo) File:Poster of Agam Puram.jpg
# Agam Puram (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Poster of...
#   infobox: <dict(13)> name, image, caption, director, producer, st...
#   pageid: 30009376
#   parsetree: <str(10248)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Agam Puram
#   wikibase: Q4691158
#   wikidata_url: https://www.wikidata.org/wiki/Q4691158
#   wikitext: <str(6255)> {{Use dmy dates|date=November 2015}}{{Use ...
# }
# en.wikipedia.org (parse) Ayyanar
# ['Sundar C Babu']
# 1690 | Sundar C Babu
# Ayyanar_(film)
# en.wikipedia.org (imageinfo) File:WLANL - jankie - Vrouwenbeelden...
# Aiyanar (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:WLANL - j...
#   infobox: <dict(12)> type, image, caption, name, other_names, scr...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 4745596
#   parsetree: <str(38245)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Aiyanar
#   wikibase: Q1318266
#   wikidata_url: https://www.wikidata.org/wiki/Q1318266
#   wikitext: <str(27000)> {{about|South Indian deity Ayyanar|Tamil ...
# }
# en.wikipedia.org (parse) Sanikizhamai Saayangalam 5 Mani
# 1691 |
# Sanikizhamai_Saayangalam_5_Mani
# Sanikizhamai Saayangalam 5 Mani (en) data
# {
#   infobox: <dict(12)> name, director, producer, studio, writer, st...
#   pageid: 44979017
#   parsetree: <str(5626)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Sanikizhamai Saayangalam 5 Mani
#   wikibase: Q19605719
#   wikidata_url: https://www.wikidata.org/wiki/Q19605719
#   wikitext: <str(3429)> {{Use dmy dates|date=February 2017}}{{Use ...
# }
# en.wikipedia.org (parse) Siddu
# ['Xavier']
# 1692 | Xavier
# Siddu
# en.wikipedia.org (imageinfo) File:Siddhu +2 poster.JPG
# Siddhu +2 (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Siddhu +2...
#   infobox: <dict(14)> name, image, director, producer, writer, sta...
#   pageid: 20357950
#   parsetree: <str(13208)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Siddhu +2
#   wikibase: Q7508172
#   wikidata_url: https://www.wikidata.org/wiki/Q7508172
#   wikitext: <str(7651)> {{Use dmy dates|date=November 2015}}{{Use ...
# }
# en.wikipedia.org (parse) Virudhagiri
# ['Dharan', 'Dharan']
# 1693 | Dharan,Dharan
# Virudhagiri
# en.wikipedia.org (imageinfo) File:Viruthagiri movie poster.jpg
# Virudhagiri (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Viruthagi...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   pageid: 29886087
#   parsetree: <str(7614)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Virudhagiri
#   wikibase: Q7935261
#   wikidata_url: https://www.wikidata.org/wiki/Q7935261
#   wikitext: <str(4121)> {{Use dmy dates|date=November 2015}}{{Use ...
# }
# en.wikipedia.org (parse) Aattanayagann
# ['Sundar C Babu']
# 1694 | Sundar C Babu
# Aattanayagann
# en.wikipedia.org (imageinfo) File:Aatanayagan.jpg
# Aattanayagann (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Aatanayag...
#   infobox: <dict(14)> name, image, director, producer, writer, sta...
#   pageid: 25034749
#   parsetree: <str(7069)> <root><template><title>Use Indian English...
#   requests: <list(2)> parse, imageinfo
#   title: Aattanayagann
#   wikibase: Q4662795
#   wikidata_url: https://www.wikidata.org/wiki/Q4662795
#   wikitext: <str(4788)> {{Use Indian English|date=November 2015}}{...
# }
# en.wikipedia.org (parse) Easan
# ['Srikanth Deva']
# 1695 | Srikanth Deva
# Easan
# en.wikipedia.org (imageinfo) File:Easan Poster.jpg
# Easan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Easan Pos...
#   infobox: <dict(17)> name, image, caption, director, producer, wr...
#   pageid: 29259915
#   parsetree: <str(16400)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Easan
#   wikibase: Q5327457
#   wikidata_url: https://www.wikidata.org/wiki/Q5327457
#   wikitext: <str(10787)> {{Use dmy dates|date=November 2015}}{{Use...
# }
# en.wikipedia.org (parse) Nil Gavani Sellathey
# ['James Vasanthan']
# 1696 | James Vasanthan
# Nil_Gavani_Sellathey
# Nil Gavani Sellathey (en) data
# {
#   infobox: <dict(13)> name, director, producer, starring, music, c...
#   pageid: 30086236
#   parsetree: <str(8602)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Nil Gavani Sellathey
#   wikibase: Q7036783
#   wikidata_url: https://www.wikidata.org/wiki/Q7036783
#   wikitext: <str(5244)> {{Use dmy dates|date=November 2015}}{{Use ...
# }
# en.wikipedia.org (parse) Manmadhan Ambu
# ['Selvaganesh']
# 1697 | Selvaganesh
# Manmadhan_Ambu
# en.wikipedia.org (imageinfo) File:Manmadhan ambu.jpg
# Manmadan Ambu (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Manmadhan...
#   infobox: <dict(17)> name, image, caption, director, producer, wr...
#   pageid: 25954897
#   parsetree: <str(33429)> <root><template><title>Use British Engli...
#   requests: <list(2)> parse, imageinfo
#   title: Manmadan Ambu
#   wikibase: Q3286029
#   wikidata_url: https://www.wikidata.org/wiki/Q3286029
#   wikitext: <str(22460)> {{Use British English|date=March 2013}}{{...
# }
# en.wikipedia.org (parse) Aridhu Aridhu
# ['Devi Sri Prasad']
# 1698 | Devi Sri Prasad
# Aridhu_Aridhu
# Aridhu Aridhu (en) data
# {
#   infobox: <dict(10)> name, caption, director, producer, starring,...
#   pageid: 30174841
#   parsetree: <str(8974)> <root><template><title>refimprove</title>...
#   requests: <list(1)> parse
#   title: Aridhu Aridhu
#   wikibase: Q4790324
#   wikidata_url: https://www.wikidata.org/wiki/Q4790324
#   wikitext: <str(4319)> {{refimprove|date=November 2019}}{{Use dmy...
# }
# en.wikipedia.org (parse) Athisaya Manal Matha
# API error: {'code': 'missingtitle', 'info': "The page you specified doesn't exist.", 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (parse) Chutti Chathan
# ['Thaman']
# 1699 | Thaman
# ex.php?title=Athisaya_Manal_Matha&action=edit&redlink=1
# Exception
# 1700 |
# Chutti_Chathan
# en.wikipedia.org (imageinfo) File:My Dear Kuttichathan.jpg
# My Dear Kuttichathan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:My Dear K...
#   infobox: <dict(15)> name, image, director, producer, writer, sta...
#   pageid: 14770549
#   parsetree: <str(31308)> <root><template><title>other uses</title...
#   requests: <list(2)> parse, imageinfo
#   title: My Dear Kuttichathan
#   wikibase: Q13114252
#   wikidata_url: https://www.wikidata.org/wiki/Q13114252
#   wikitext: <str(21481)> {{other uses|Kuttichathan (disambiguation...
# }
# en.wikipedia.org (parse) Nellu
# ['Ilaiyaraaja', 'Malayalam', 'Tamil versions', 'Anu Malik', 'Anand', 'Milind', 'Laxmikant', 'Pyarelal', 'Hindi version']
# 1701 | Ilaiyaraaja,Malayalam,Tamil versions,Anu Malik,Anand,Milind,Laxmikant,Pyarelal,Hindi version
# Nellu_(2010_film)
# Nellu (en) data
# {
#   pageid: 31665900
#   parsetree: <str(258)> <root>'''Nellu''' may refer to* [[Nellu (1...
#   requests: <list(1)> parse
#   title: Nellu
#   wikibase: Q16798415
#   wikidata_url: https://www.wikidata.org/wiki/Q16798415
#   wikitext: <str(199)> '''Nellu''' may refer to* [[Nellu (1974 fil...
# }
# en.wikipedia.org (parse) Thenmerku Paruvakaatru
# 1702 |
# Thenmerku_Paruvakaatru
# en.wikipedia.org (imageinfo) File:Thenmerku Paruvakaatru.jpg
# Thenmerku Paruvakaatru (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Thenmerku...
#   infobox: <dict(14)> name, image, director, producer, writer, sta...
#   pageid: 30177188
#   parsetree: <str(13115)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Thenmerku Paruvakaatru
#   wikibase: Q7781398
#   wikidata_url: https://www.wikidata.org/wiki/Q7781398
#   wikitext: <str(8096)> {{short description|2010 film by Seenu Ram...
# }
# en.wikipedia.org (parse) Kotti
# ['N. R. Raghunanthan']
# 1703 | N. R. Raghunanthan
# Kotti
# Kotti (en) data
# {
#   infobox: <dict(10)> name, director, producer, writer, starring, ...
#   pageid: 30257046
#   parsetree: <str(3054)> <root><template><title>for</title><part><...
#   requests: <list(1)> parse
#   title: Kotti
#   wikibase: Q6434338
#   wikidata_url: https://www.wikidata.org/wiki/Q6434338
#   wikitext: <str(1126)> {{for|the Finnish basketball player|Tuukka...
# }
# en.wikipedia.org (parse) Mudhal Kadhal Mazhai
# ['Guru Kalyan']
# 1704 | Guru Kalyan
# Mudhal_Kadhal_Mazhai
# Mahendran (actor) (en) data
# {
#   infobox: <dict(6)> name, birth_date, birth_place, othername(s), ...
#   pageid: 41501426
#   parsetree: <str(11139)> <root><template><title>About</title><par...
#   requests: <list(1)> parse
#   title: Mahendran (actor)
#   wikibase: Q6733789
#   wikidata_url: https://www.wikidata.org/wiki/Q6733789
#   wikitext: <str(8181)> {{About||the actor of the same name|J. Mah...
# }
# en.wikipedia.org (parse) Nalamdhana
# 1705 |
# Nalamdhana
# Nalamdhana (en) data
# {
#   infobox: <dict(7)> name, director, starring, music, released, co...
#   pageid: 30516505
#   parsetree: <str(4798)> <root><ignore>&lt;noinclude&gt;</ignore><...
#   requests: <list(1)> parse
#   title: Nalamdhana
#   wikibase: Q6960786
#   wikidata_url: https://www.wikidata.org/wiki/Q6960786
#   wikitext: <str(2032)> <noinclude><!-- Please do not remove or ch...
# }
# en.wikipedia.org (parse) Villalan
# ['Chanakya']
# 1706 | Chanakya
# Villalan
# ['Ravi Raghav']
# 1707 | Ravi Raghav
# Villalan (en) data
# {
#   infobox: <dict(9)> name, director, starring, music, cinematograp...
#   pageid: 30516575
#   parsetree: <str(3510)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Villalan
#   wikibase: Q7930837
#   wikidata_url: https://www.wikidata.org/wiki/Q7930837
#   wikitext: <str(1299)> {{Use dmy dates|date=November 2015}}{{Use ...
# }

# %%
print('OVER')
# Out:
# OVER

# %%
# |def getmusicdir(movie,year):
#   #print(wikipedia.search(movie))
#   try:
#     #title=wikipedia.page(movie).url[30:]
#     #print(title+'|'+movie+" "+year+" tamil")
#     so = wptools.page(movie).get_parse()
#     infobox = so.data['infobox']
#     if infobox is not None:
#       if 'music' in infobox.keys():
#         #print(infobox['music'])
#         alphanumeric = ""
#         for char in infobox['music']:
#           if char.isalnum():
#             alphanumeric += char
#           elif char is ' ':
#             alphanumeric += char
#           else:
#             alphanumeric += '-'
            
#         music_dir=[]
#         for part in alphanumeric.split('-'):
#           if part is not '' and part is not ' ':
#             music_dir.append(part)
        
#         music_list=[]
#         for dist in music_dir:
#           if dist.lower().strip() not in ['br','\n','editor','nbsp','music director','small','Songs','Score','Original Songs','Background Score'] and len(dist.lower().strip()):
#             music_list.append(dist)
#         print(music_list)
#         return music_list
#       return []
#     return []
#   except:
#     print("Exception");
#     return []

# %%
data
# Out:
#       year  ...               music
# 0     2020  ...
# 1     2020  ...
# 2     2020  ...
# 3     2020  ...
# 4     2020  ...
# ...    ...  ...                 ...
# 1703  2010  ...  N. R. Raghunanthan
# 1704  2010  ...         Guru Kalyan
# 1705  2010  ...
# 1706  2010  ...            Chanakya
# 1707  2010  ...         Ravi Raghav
#
# [1708 rows x 8 columns]

# %%
data.to_csv('datav2.1.csv')
from google.colab import files
files.download('datav2.1.csv')

# %%
r=data.iloc[0]
r
# Out:
# year                                  2020
# title                        Anantha Veedu
# director                         Sugumaran
# cast        Sugumaran, Shivayam, Nagarajan
# genre                                  NaN
# producer                 Nila Movie Makers
# link                                   NaN
# music                          Ravi Raghav
# Name: 0, dtype: object

# %%
data.at[0,'music']='ddd'

# %%
data
# Out:
#       year  ...        music
# 0     2020  ...          ddd
# 1     2020  ...  Ravi Raghav
# 2     2020  ...  Ravi Raghav
# 3     2020  ...  Ravi Raghav
# 4     2020  ...  Ravi Raghav
# ...    ...  ...          ...
# 1703  2010  ...  Ravi Raghav
# 1704  2010  ...  Ravi Raghav
# 1705  2010  ...  Ravi Raghav
# 1706  2010  ...  Ravi Raghav
# 1707  2010  ...  Ravi Raghav
#
# [1708 rows x 8 columns]

# %%
data.at[0,'TESTER']="test"

# %%
data
# Out:
#       year                               title  ...               music TESTER
# 0     2020                       Anantha Veedu  ...                       test
# 1     2020                     Ayya Ullen Ayya  ...                        NaN
# 2     2020  En Sangathu Aala Adichavan Evanada  ...                        NaN
# 3     2020                     Kadhal Vizhigal  ...                        NaN
# 4     2020                      Pachai Vilakku  ...                        NaN
# ...    ...                                 ...  ...                 ...    ...
# 1703  2010              Thenmerku Paruvakaatru  ...  N. R. Raghunanthan    NaN
# 1704  2010                               Kotti  ...         Guru Kalyan    NaN
# 1705  2010                Mudhal Kadhal Mazhai  ...                        NaN
# 1706  2010                          Nalamdhana  ...            Chanakya    NaN
# 1707  2010                            Villalan  ...         Ravi Raghav    NaN
#
# [1708 rows x 9 columns]
